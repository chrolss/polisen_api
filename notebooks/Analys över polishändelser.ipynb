# %% [markdown]
# Analys över polishändelser i Sverige

# %%
# %config IPCompleter.greedy=True
import requests
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
from sqlalchemy import create_engine, MetaData, Table

# %%
url = 'https://polisen.se/api/events'                  # Gets the 500 latest events
#url = 'https://polisen.se/api/events?DateTime=2019-01' # Gets the event for january 2019 (500 items max)
response = requests.get(url)
print(type(response))
rjs = response.json()   # Save the response in json format for easy parsing, but this is a list containing dicts
# Out:
# <class 'requests.models.Response'>

# %%
idl = []
datetimel = []
namel = []
summaryl = []
urll = []
typel = []
location_namel = []
longitudel = []
latitudel = []
for element in rjs:
    idl.append(element['id'])
    datetimel.append(element['datetime'])
    namel.append(element['name'])
    summaryl.append(element['summary'])
    urll.append(element['url'])
    typel.append(element['type'])
    location_namel.append(element['location']['name'])
    latlong_temp = element['location']['gps'].split(',')
    longitudel.append(latlong_temp[0])
    latitudel.append(latlong_temp[1])

# %%
df = pd.DataFrame({'id': idl,
                  'datetime': datetimel,
                  'name': namel,
                  'summary': summaryl,
                  'url': urll,
                  'type': typel,
                  'location': location_namel,
                  'longitude': longitudel,
                  'latitude': latitudel})

# %%
df.head()
# Out:
#        id                    datetime  \
# 0  172409   2019-11-14 9:00:30 +01:00
# 1  172416  2019-11-14 10:49:20 +01:00
# 2  172407   2019-11-14 9:38:00 +01:00
# 3  172414  2019-11-14 10:43:53 +01:00
# 4  172279   2019-11-13 8:28:04 +01:00
#
#                                           name  \
# 0       14 november 09:00, Misshandel, Ludvika
# 1  14 november 10:49, Trafikolycka, Norrköping
# 2   14 november 09:38, Trafikolycka, Jönköping
# 3  14 november 10:43, Trafikolycka, Norrköping
# 4                 13 november 08:28, Rån, Håbo
#
#                                              summary  \
# 0             En misshandel har skett i Grängesberg.
# 1              Cyklist påkörd i centrala Norrköping.
# 2  En lastbil med släp har vält på riksväg 26 i Ryd.
# 3    Krock mellan bilar på riksväg 51 vid Svärtinge.
# 4  En ung man har rånats på alla sina kläder. En ...
#
#                                                  url          type  \
# 0  https://polisen.se/aktuellt/handelser/2019/nov...    Misshandel
# 1  https://polisen.se/aktuellt/handelser/2019/nov...  Trafikolycka
# 2  https://polisen.se/aktuellt/handelser/2019/nov...  Trafikolycka
# 3  https://polisen.se/aktuellt/handelser/2019/nov...  Trafikolycka
# 4  https://polisen.se/aktuellt/handelser/2019/nov...           Rån
#
#      location  longitude   latitude
# 0     Ludvika  60.152358  15.191639
# 1  Norrköping  58.587745  16.192421
# 2   Jönköping  57.782614  14.161788
# 3  Norrköping  58.587745  16.192421
# 4        Håbo  59.627071  17.452298

# %%
print('earliest: ' + str(df.datetime.min()) + " and latest:" + str(df.datetime.max()))
# Out:
# earliest: 2019-11-03 13:29:04 +01:00 and latest:2019-11-14 9:50:55 +01:00

# %%
print("number of unique categories:  " + str(len(df.type.unique())))
print(df.type.value_counts().head())
# Out:
# number of unique categories:  57
# Trafikolycka           98
# Övrigt                 53
# Trafikolycka, vilt     37
# Rattfylleri            23
# Sammanfattning natt    22
# Name: type, dtype: int64

# %%
import folium

# %% [markdown]
# Create a map with markers corresponding to all event locations

# %%
# Make an empty map
m = folium.Map(location=[20, 0], tiles="OpenStreetMap", zoom_start=2)
 
# I can add marker one by one on the map
for i in range(0,len(df)):
    folium.Marker([df.iloc[i]['longitude'], df.iloc[i]['latitude']], popup=df.iloc[i]['location']).add_to(m)
 
# Save it as html
m.save('312_markers_on_folium_map1.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Create a map with density depending on the report type

# %%
# Create a dataframe only containing trafic accidents
ta = df[df['type'].isin(['Trafikolycka', 'Trafikolycka, vilt'])]
oc_dic = dict()
for place in ta.location:
    if place in oc_dic.keys():
        oc_dic[place] += 1
    else:
        oc_dic[place] = 1

# %%
# Make an empty map
m = folium.Map(location=[59.334591,18.063240], tiles="OpenStreetMap", zoom_start=2)
 
# Add markers with size based on number of occurances?
for i in range(0,len(ta)):
   folium.Circle(
      location=[ta.iloc[i]['longitude'], ta.iloc[i]['latitude']],
      popup=ta.iloc[i]['location'],
      radius=oc_dic[ta.iloc[i]['location']]*10000,
      color='crimson',
      fill=True,
      fill_color='crimson'
   ).add_to(m)
 
# Save it as html
m.save('mymap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's investigate bomb threats and detonations

# %%
boom = df[df['type'].isin(['Detonation', 'Bombhot'])]

# %%
boom.head()
# Out:
#          id                    datetime  \
# 186  172010  2019-11-11 23:57:20 +01:00
# 323  171835   2019-11-11 1:25:04 +01:00
# 433  171720  2019-11-09 20:57:52 +01:00
#
#                                            name  \
# 186   11 november 23:57, Detonation, Hässleholm
# 323  11 november 01:25, Detonation, Helsingborg
# 433        09 november 20:57, Detonation, Malmö
#
#                                            summary  \
# 186  Detonation i anslutning till garage, Sösdala.
# 323   Detonation på Östra Sandgatan i Helsingborg.
# 433                 Larm om hög smäll, Hästhagen.
#
#                                                    url        type  \
# 186  https://polisen.se/aktuellt/handelser/2019/nov...  Detonation
# 323  https://polisen.se/aktuellt/handelser/2019/nov...  Detonation
# 433  https://polisen.se/aktuellt/handelser/2019/nov...  Detonation
#
#         location  longitude   latitude
# 186   Hässleholm  56.158915  13.766765
# 323  Helsingborg  56.046467  12.694512
# 433        Malmö  55.604981  13.003822

# %%
sthlm = df[df['location'] == 'Stockholm']

# %%
sthlm
# Out:
#          id                    datetime  \
# 1    172270  2019-11-13 13:16:05 +01:00
# 4    172267  2019-11-13 13:09:01 +01:00
# 71   172147  2019-11-12 17:15:03 +01:00
# 94   172150  2019-11-12 18:24:03 +01:00
# 108  172140  2019-11-12 17:38:09 +01:00
# 113  172136  2019-11-12 15:37:02 +01:00
# 115  172135  2019-11-12 15:06:02 +01:00
# 144  172078  2019-11-12 12:23:17 +01:00
# 216  171978  2019-11-11 16:02:37 +01:00
# 234  171958  2019-11-11 17:47:07 +01:00
# 250  171941  2019-11-11 16:08:54 +01:00
# 279  171891  2019-11-11 11:13:07 +01:00
# 288  171873   2019-11-11 9:13:30 +01:00
# 314  171848   2019-11-11 2:41:46 +01:00
# 343  171815  2019-11-10 15:39:16 +01:00
# 347  171804  2019-11-10 12:22:31 +01:00
# 361  171800  2019-11-10 14:21:17 +01:00
# 399  171751   2019-11-10 5:39:02 +01:00
